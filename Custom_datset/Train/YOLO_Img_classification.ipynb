# %%
from ultralytics import YOLO

# Load YOLO classification model
model = YOLO("yolo11s-cls.pt")

# Correct training syntax
results = model.train(
    data="C:/Users/Aditya Sikarwar/Desktop/YOLO//Custom_dataset",  # 👈 must use data=
    epochs=10,
    imgsz=640
)
# Out:
# WARNING yolo11s-cls.pt appears to require 'torch.utils.serialization', which is not in Ultralytics requirements.
# AutoInstall will run now for 'torch.utils.serialization' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official Ultralytics model, i.e. 'yolo predict model=yolo11n.pt'
# requirements: Ultralytics requirement ['torch.utils.serialization'] not found, attempting AutoUpdate...
# WARNING Retry 1/2 failed: Command 'pip install --no-cache-dir "torch.utils.serialization" ' returned non-zero exit status 1.
# WARNING Retry 2/2 failed: Command 'pip install --no-cache-dir "torch.utils.serialization" ' returned non-zero exit status 1.
# WARNING requirements:  Command 'pip install --no-cache-dir "torch.utils.serialization" ' returned non-zero exit status 1.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\nn\tasks.py:1409, in torch_safe_load(weight, safe_only)
#    1408         else:
# -> 1409             ckpt = torch_load(file, map_location="cpu")
#    1411 except ModuleNotFoundError as e:  # e.name is missing module name
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\utils\patches.py:116, in torch_load(*args, **kwargs)
#     114     kwargs["weights_only"] = False
# --> 116 return torch.load(*args, **kwargs)
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\torch\serialization.py:1475, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1474 def persistent_load(saved_id):
# -> 1475     if isinstance(saved_id, tuple):
#    1476         # Ignore containers that don't have any sources saved
#    1477         if all(saved_id[1:]):
#
# ModuleNotFoundError: No module named 'torch.utils.serialization'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 4
#       1 from ultralytics import YOLO
#       3 # Load YOLO classification model
# ----> 4 model = YOLO("yolo11s-cls.pt")
#       6 # Correct training syntax
#       7 results = model.train(
#       8     data="C:/Users/Aditya Sikarwar/Desktop/YOLO//Custom_dataset",  # 👈 must use data=
#       9     epochs=10,
#      10     imgsz=640
#      11 )
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\models\yolo\model.py:81, in YOLO.__init__(self, model, task, verbose)
#      78     self.__dict__ = new_instance.__dict__
#      79 else:
#      80     # Continue with default YOLO initialization
# ---> 81     super().__init__(model=model, task=task, verbose=verbose)
#      82     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      83         from ultralytics import RTDETR
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\engine\model.py:149, in Model.__init__(self, model, task, verbose)
#     147     self._new(model, task=task, verbose=verbose)
#     148 else:
# --> 149     self._load(model, task=task)
#     151 # Delete super().training for accessing self.model.training
#     152 del self.training
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\engine\model.py:288, in Model._load(self, weights, task)
#     285 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     287 if str(weights).rpartition(".")[-1] == "pt":
# --> 288     self.model, self.ckpt = load_checkpoint(weights)
#     289     self.task = self.model.task
#     290     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\nn\tasks.py:1461, in load_checkpoint(weight, device, inplace, fuse)
#    1448 def load_checkpoint(weight, device=None, inplace=True, fuse=False):
#    1449     """Load a single model weights.
#    1450
#    1451     Args:
#    (...)
#    1459         ckpt (dict): Model checkpoint dictionary.
#    1460     """
# -> 1461     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1462     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1463     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\nn\tasks.py:1435, in torch_safe_load(weight, safe_only)
#    1428     LOGGER.warning(
#    1429         f"{weight} appears to require '{e.name}', which is not in Ultralytics requirements."
#    1430         f"\nAutoInstall will run now for '{e.name}' but this feature will be removed in the future."
#    1431         f"\nRecommend fixes are to train a new model using the latest 'ultralytics' package or to "
#    1432         f"run a command with an official Ultralytics model, i.e. 'yolo predict model=yolo11n.pt'"
#    1433     )
#    1434     check_requirements(e.name)  # install missing module
# -> 1435     ckpt = torch_load(file, map_location="cpu")
#    1437 if not isinstance(ckpt, dict):
#    1438     # File is likely a YOLO instance saved with i.e. torch.save(model, "saved_model.pt")
#    1439     LOGGER.warning(
#    1440         f"The file '{weight}' appears to be improperly saved or formatted. "
#    1441         f"For optimal results, use model.save('filename.pt') to correctly save YOLO models."
#    1442     )
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\utils\patches.py:116, in torch_load(*args, **kwargs)
#     113 if TORCH_1_13 and "weights_only" not in kwargs:
#     114     kwargs["weights_only"] = False
# --> 116 return torch.load(*args, **kwargs)
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\torch\serialization.py:1475, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1474 def persistent_load(saved_id):
# -> 1475     if isinstance(saved_id, tuple):
#    1476         # Ignore containers that don't have any sources saved
#    1477         if all(saved_id[1:]):
#    1478             _check_container_source(*saved_id)
#
# ModuleNotFoundError: No module named 'torch.utils.serialization'

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU found")
# Out:
# False
# No GPU found

# %%
from ultralytics import YOLO
model = YOLO("runs/classify/train11/weights/best.pt")
model.export(format="openvino")
# Out:
# WARNING runs/classify/train11/weights/best.pt appears to require 'torch.utils.serialization', which is not in Ultralytics requirements.
# AutoInstall will run now for 'torch.utils.serialization' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official Ultralytics model, i.e. 'yolo predict model=yolo11n.pt'
# requirements: Ultralytics requirement ['torch.utils.serialization'] not found, attempting AutoUpdate...
# WARNING Retry 1/2 failed: Command 'pip install --no-cache-dir "torch.utils.serialization" ' returned non-zero exit status 1.
# WARNING Retry 2/2 failed: Command 'pip install --no-cache-dir "torch.utils.serialization" ' returned non-zero exit status 1.
# WARNING requirements:  Command 'pip install --no-cache-dir "torch.utils.serialization" ' returned non-zero exit status 1.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\nn\tasks.py:1409, in torch_safe_load(weight, safe_only)
#    1408         else:
# -> 1409             ckpt = torch_load(file, map_location="cpu")
#    1411 except ModuleNotFoundError as e:  # e.name is missing module name
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\utils\patches.py:116, in torch_load(*args, **kwargs)
#     114     kwargs["weights_only"] = False
# --> 116 return torch.load(*args, **kwargs)
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\torch\serialization.py:1475, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1474 def persistent_load(saved_id):
# -> 1475     if isinstance(saved_id, tuple):
#    1476         # Ignore containers that don't have any sources saved
#    1477         if all(saved_id[1:]):
#
# ModuleNotFoundError: No module named 'torch.utils.serialization'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from ultralytics import YOLO
# ----> 2 model = YOLO("runs/classify/train11/weights/best.pt")
#       3 model.export(format="openvino")
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\models\yolo\model.py:81, in YOLO.__init__(self, model, task, verbose)
#      78     self.__dict__ = new_instance.__dict__
#      79 else:
#      80     # Continue with default YOLO initialization
# ---> 81     super().__init__(model=model, task=task, verbose=verbose)
#      82     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      83         from ultralytics import RTDETR
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\engine\model.py:149, in Model.__init__(self, model, task, verbose)
#     147     self._new(model, task=task, verbose=verbose)
#     148 else:
# --> 149     self._load(model, task=task)
#     151 # Delete super().training for accessing self.model.training
#     152 del self.training
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\engine\model.py:288, in Model._load(self, weights, task)
#     285 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     287 if str(weights).rpartition(".")[-1] == "pt":
# --> 288     self.model, self.ckpt = load_checkpoint(weights)
#     289     self.task = self.model.task
#     290     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\nn\tasks.py:1461, in load_checkpoint(weight, device, inplace, fuse)
#    1448 def load_checkpoint(weight, device=None, inplace=True, fuse=False):
#    1449     """Load a single model weights.
#    1450
#    1451     Args:
#    (...)
#    1459         ckpt (dict): Model checkpoint dictionary.
#    1460     """
# -> 1461     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1462     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1463     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\nn\tasks.py:1435, in torch_safe_load(weight, safe_only)
#    1428     LOGGER.warning(
#    1429         f"{weight} appears to require '{e.name}', which is not in Ultralytics requirements."
#    1430         f"\nAutoInstall will run now for '{e.name}' but this feature will be removed in the future."
#    1431         f"\nRecommend fixes are to train a new model using the latest 'ultralytics' package or to "
#    1432         f"run a command with an official Ultralytics model, i.e. 'yolo predict model=yolo11n.pt'"
#    1433     )
#    1434     check_requirements(e.name)  # install missing module
# -> 1435     ckpt = torch_load(file, map_location="cpu")
#    1437 if not isinstance(ckpt, dict):
#    1438     # File is likely a YOLO instance saved with i.e. torch.save(model, "saved_model.pt")
#    1439     LOGGER.warning(
#    1440         f"The file '{weight}' appears to be improperly saved or formatted. "
#    1441         f"For optimal results, use model.save('filename.pt') to correctly save YOLO models."
#    1442     )
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\utils\patches.py:116, in torch_load(*args, **kwargs)
#     113 if TORCH_1_13 and "weights_only" not in kwargs:
#     114     kwargs["weights_only"] = False
# --> 116 return torch.load(*args, **kwargs)
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\torch\serialization.py:1475, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1474 def persistent_load(saved_id):
# -> 1475     if isinstance(saved_id, tuple):
#    1476         # Ignore containers that don't have any sources saved
#    1477         if all(saved_id[1:]):
#    1478             _check_container_source(*saved_id)
#
# ModuleNotFoundError: No module named 'torch.utils.serialization'
