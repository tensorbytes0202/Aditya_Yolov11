# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# False
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 import torch
#       2 print(torch.cuda.is_available())
# ----> 3 print(torch.cuda.get_device_name(0))
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\torch\cuda\__init__.py:582, in get_device_name(device)
#     570 def get_device_name(device: "Device" = None) -> str:
#     571     r"""Get the name of a device.
#     572
#     573     Args:
#    (...)
#     580         str: the name of the device
#     581     """
# --> 582     return get_device_properties(device).name
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\torch\cuda\__init__.py:614, in get_device_properties(device)
#     602 def get_device_properties(device: "Device" = None) -> _CudaDeviceProperties:
#     603     r"""Get the properties of a device.
#     604
#     605     Args:
#    (...)
#     612         _CudaDeviceProperties: the properties of the device
#     613     """
# --> 614     _lazy_init()  # will define _get_device_properties
#     615     device = _get_device_index(device, optional=True)
#     616     if device < 0 or device >= device_count():
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\torch\cuda\__init__.py:403, in _lazy_init()
#     398     raise RuntimeError(
#     399         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     400         "multiprocessing, you must use the 'spawn' start method"
#     401     )
#     402 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403     raise AssertionError("Torch not compiled with CUDA enabled")
#     404 if _cudart is None:
#     405     raise AssertionError(
#     406         "libcudart functions unavailable. It looks like you have a broken build?"
#     407     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")

results = model.train(
    data= "dataset\data.yaml",
    epochs=5,
    imgsz=640,
    device="GPU",
    batch=4
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.226 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.225  Python-3.10.7 torch-2.9.0+cpu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       1 from ultralytics import YOLO
#       3 model = YOLO("yolo11n.pt")
# ----> 5 results = model.train(
#       6     data= "dataset\data.yaml",
#       7     epochs=5,
#       8     imgsz=640,
#       9     device="GPU",
#      10     batch=4
#      11 )
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\engine\model.py:772, in Model.train(self, trainer, **kwargs)
#     769 if args.get("resume"):
#     770     args["resume"] = self.ckpt_path
# --> 772 self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     773 if not args.get("resume"):  # manually set model only if not resuming
#     774     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\models\yolo\detect\train.py:63, in DetectionTrainer.__init__(self, cfg, overrides, _callbacks)
#      55 def __init__(self, cfg=DEFAULT_CFG, overrides: dict[str, Any] | None = None, _callbacks=None):
#      56     """Initialize a DetectionTrainer object for training YOLO object detection model training.
#      57
#      58     Args:
#    (...)
#      61         _callbacks (list, optional): List of callback functions to be executed during training.
#      62     """
# ---> 63     super().__init__(cfg, overrides, _callbacks)
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\engine\trainer.py:126, in BaseTrainer.__init__(self, cfg, overrides, _callbacks)
#     124 self.args = get_cfg(cfg, overrides)
#     125 self.check_resume(overrides)
# --> 126 self.device = select_device(self.args.device)
#     127 # Update "-1" devices so post-training val does not repeat search
#     128 self.args.device = os.getenv("CUDA_VISIBLE_DEVICES") if "cuda" in str(self.device) else str(self.device)
#
# File c:\Users\Aditya Sikarwar\Desktop\YOLO\myvenv\lib\site-packages\ultralytics\utils\torch_utils.py:198, in select_device(device, newline, verbose)
#     191         LOGGER.info(s)
#     192         install = (
#     193             "See https://pytorch.org/get-started/locally/ for up-to-date torch install instructions if no "
#     194             "CUDA devices are seen by torch.\n"
#     195             if torch.cuda.device_count() == 0
#     196             else ""
#     197         )
# --> 198         raise ValueError(
#     199             f"Invalid CUDA 'device={device}' requested."
#     200             f" Use 'device=cpu' or pass valid CUDA device(s) if available,"
#     201             f" i.e. 'device=0' or 'device=0,1,2,3' for Multi-GPU.\n"
#     202             f"\ntorch.cuda.is_available(): {torch.cuda.is_available()}"
#     203             f"\ntorch.cuda.device_count(): {torch.cuda.device_count()}"
#     204             f"\nos.environ['CUDA_VISIBLE_DEVICES']: {visible}\n"
#     205             f"{install}"
#     206         )
#     208 if not cpu and not mps and torch.cuda.is_available():  # prefer GPU if available
#     209     devices = device.split(",") if device else "0"  # i.e. "0,1" -> ["0", "1"]
#
# ValueError: Invalid CUDA 'device=gpu' requested. Use 'device=cpu' or pass valid CUDA device(s) if available, i.e. 'device=0' or 'device=0,1,2,3' for Multi-GPU.
#
# torch.cuda.is_available(): False
# torch.cuda.device_count(): 0
# os.environ['CUDA_VISIBLE_DEVICES']: 1
# See https://pytorch.org/get-started/locally/ for up-to-date torch install instructions if no CUDA devices are seen by torch.
