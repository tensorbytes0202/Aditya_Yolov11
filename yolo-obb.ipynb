# %%
from ultralytics import YOLO

model = YOLO("YOLO11n-obb.pt") # type: ignore

results = model("20250424_100231.mp4",save=True)
results[0].show()
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/755) c:\Users\Aditya Sikarwar\Desktop\YOLO\20250424_100231.mp4: 576x1024 3 large vehicles, 289.4ms
# video 1/1 (frame 2/755) c:\Users\Aditya Sikarwar\Desktop\YOLO\20250424_100231.mp4: 576x1024 (no detections), 201.9ms
# video 1/1 (frame 3/755) c:\Users\Aditya Sikarwar\Desktop\YOLO\20250424_100231.mp4: 576x1024 (no detections), 217.5ms
# ...
