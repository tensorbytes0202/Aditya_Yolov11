# %%
# YOLOv8 Video Detection - Optimized
# Make sure ultralytics is installed: pip install ultralytics

from ultralytics import YOLO
import cv2

# 1️⃣ Load YOLOv8 model (replace with your model path)
model = YOLO("yolo11n.pt")  # or "yolov8n.pt" if you want pre-trained

# 2️⃣ Input video path
video_path = "IMG_2631 2.MOV"

# 3️⃣ Output directory / file
output_video_path = "runs/detect/video_output.mp4"

# 4️⃣ Open video with OpenCV
cap = cv2.VideoCapture(video_path)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# VideoWriter to save output
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# 5️⃣ Process video frame by frame (stream=True avoids memory issues)
results = model(video_path, stream=True)  # generator of Results

for r in results:
    # r.orig_img is the original frame with annotations (bounding boxes)
    frame = r.orig_img

    # 6️⃣ Display the frame
    cv2.imshow("YOLOv8 Detection", frame)

    # 7️⃣ Save the frame to output video
    out.write(frame)

    # 8️⃣ Exit if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 9️⃣ Release resources
cap.release()
out.release()
cv2.destroyAllWindows()

print(f"✅ Video saved to: {output_video_path}")

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt") # type: ignore

results = model("Wo humsafar se baate .jpg",save=True)
results[0].show()
# Out:
# image 1/1 c:\Users\Aditya Sikarwar\Desktop\YOLO\Wo humsafar se baate .jpg: 640x544 2 persons, 1 train, 2 backpacks, 144.5ms
# Speed: 4.8ms preprocess, 144.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to C:\Users\Aditya Sikarwar\runs\detect\predict7
