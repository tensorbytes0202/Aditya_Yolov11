# %%
from ultralytics import YOLO
model = YOLO("YOLO11s-cls.pt")
results = model.train(data="Custom_dataset",epochs=6,imgsz=640)
# Out:
# Ultralytics 8.3.225  Python-3.10.7 torch-2.9.0+cpu CPU (Intel Core Ultra 5 125H)
# ...

# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO(r"C:\\Users\Aditya Sikarwar\\runs\\classify\\train12\weights\best.pt")

# Run inference on a test image
results = model("34571582172_efa4946a45_n.jpg")

# Show result
results[0].show()
# Out:
# image 1/1 c:\Users\Aditya Sikarwar\Desktop\YOLO\34571582172_efa4946a45_n.jpg: 640x640 dandelion 0.91, daisy 0.09, 159.1ms
# Speed: 50.4ms preprocess, 159.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
