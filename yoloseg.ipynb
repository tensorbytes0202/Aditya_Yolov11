# %%
from ultralytics import YOLO

model = YOLO("YOLO11n-seg.pt") # type: ignore

results = model("Wo humsafar se baate .jpg",save=True)
results[0].show()
# Out:
# image 1/1 c:\Users\Aditya Sikarwar\Desktop\YOLO\Wo humsafar se baate .jpg: 640x544 2 persons, 1 train, 1 backpack, 2 handbags, 431.2ms
# Speed: 10.6ms preprocess, 431.2ms inference, 25.6ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to C:\Users\Aditya Sikarwar\runs\segment\predict

# %%
from ultralytics import YOLO

model = YOLO("YOLO11n-pose.pt") # type: ignore

results = model("Wo humsafar se baate .jpg",save=True)
results[0].show()
# Out:
# image 1/1 c:\Users\Aditya Sikarwar\Desktop\YOLO\Wo humsafar se baate .jpg: 640x544 2 persons, 97.0ms
# Speed: 11.9ms preprocess, 97.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 544)
# Results saved to C:\Users\Aditya Sikarwar\runs\pose\predict2

# %%
from ultralytics import YOLO

model = YOLO("YOLO11n-cls.pt") # type: ignore

results = model("Wo humsafar se baate .jpg",save=True)
results[0].show()
# Out:
# image 1/1 c:\Users\Aditya Sikarwar\Desktop\YOLO\Wo humsafar se baate .jpg: 224x224 go-kart 0.48, punching_bag 0.05, knee_pad 0.03, crash_helmet 0.02, bobsled 0.01, 23.4ms
# Speed: 79.1ms preprocess, 23.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to C:\Users\Aditya Sikarwar\runs\classify\predict2
